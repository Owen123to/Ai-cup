# %%
import tensorflow as tf
from tensorflow.keras.models import Model, load_model
# from tensorflow.keras.layers import Conv2D, ReLU, Flatten, Dense, Softmax, BatchNormalization, Input, ZeroPadding2D, Activation
from tensorflow.keras.layers import Input, Conv2D, ReLU, BatchNormalization, Add, MaxPooling2D, Flatten, Dense, Softmax, Activation, GlobalAveragePooling2D, ZeroPadding2D
from tensorflow.keras.optimizers import Adam, Nadam, SGD
import keras
import numpy as np
import h5py

# %%
tf.__version__
tf.test.is_gpu_available()
# Out:
# WARNING:tensorflow:From C:\Users\kenny\AppData\Local\Temp\ipykernel_2704\3793539530.py:2: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# True

# %%
def dataGenerator(start_index, stop_index):
    def generator():
        indexes = shuff[start_index : stop_index]
        for i in indexes:
            x = np.array(hdf5['Xs'][i])
            y = np.array(hdf5['Ys'][i])
            yield x, y
    return generator

# %%
hdf5 = h5py.File('./hdf5/kyu_dataset.hdf5','r')
# for j in range (0, 13):
#     print(hdf5['xs'][50][j])
# xs = hdf5.get('Xs')
# ys = hdf5.get('Ys')
batch_size = 64
dataset_size = hdf5['Xs'].shape[0]
val_start = 0.8
val_stop = 1.0

train_steps = int(dataset_size * (val_start)/batch_size)
val_steps = int(dataset_size * (val_stop - val_start)/batch_size)
print(f"train_steps: {train_steps}, val_steps: {val_steps}")
shuff = np.arange(dataset_size)
np.random.shuffle(shuff)

data_gen = dataGenerator(start_index = 0, stop_index = int(dataset_size * val_start)) # 90% of the complete dataset
dataset = tf.data.Dataset.from_generator(data_gen, 
                                         output_types=(tf.dtypes.float32, tf.dtypes.int32),
                                         output_shapes=(tf.TensorShape((19,19,19)),tf.TensorShape((1))))
dataset = dataset.batch(batch_size, drop_remainder=True)
dataset = dataset.prefetch(tf.data.AUTOTUNE)

data_gen_valid = dataGenerator(start_index=int(dataset_size * val_start), # 10% of the complete dataset
                               stop_index=int(dataset_size * val_stop))
dataset_valid = tf.data.Dataset.from_generator(data_gen_valid, 
                                         output_types=(tf.dtypes.float32, tf.dtypes.int32),
                                         output_shapes=(tf.TensorShape((19,19,19)),tf.TensorShape((1))))
dataset_valid = dataset_valid.batch(batch_size, drop_remainder=True)
dataset_valid = dataset_valid.prefetch(tf.data.AUTOTUNE)
# Out:
# train_steps: 169592, val_steps: 42398

# %%
# resnet50
def block1(x, filters, kernel_size=3, stride=1, conv_shortcut=False):
    bn_axis=3
#     x = BatchNormalization(axis=bn_axis, epsilon=1.001e-5)(x)
    preact = Activation("relu")(x)
    if conv_shortcut:
        shortcut = Conv2D(4 * filters, 1, strides=stride)(preact)
    else:
        shortcut = x
    
    x = Conv2D(filters, 1, strides=1, use_bias=False)(preact)
#     x = BatchNormalization(axis=bn_axis, epsilon=1.001e-5)(x)
    x = Activation("relu")(x)
    x = ZeroPadding2D(padding=((1, 1), (1, 1)))(x)
    x = Conv2D(
        filters,
        kernel_size,
        strides=stride,
        use_bias=False
    )(x)
#     x = BatchNormalization(axis=bn_axis, epsilon=1.001e-5)(x)
    x = Activation("relu")(x)
    x = Conv2D(4 * filters, 1)(x)
    x = Add()([shortcut, x])
    return x

def ResNet50(include_top=True,
             input_tensor=None,
             input_shape=None,
             pooling=False):
    inputs = Input(shape = input_shape)
    x = block1(inputs, 256, conv_shortcut=True)
    x = block1(x, 256)
    x = block1(x, 256)
    x = block1(x, 256)
    x = block1(x, 256)
    x = block1(x, 256)
    x = block1(x, 256)
    x = block1(x, 256)
    x = block1(x, 256)
    x = block1(x, 256)
    x = block1(x, 256)
    x = block1(x, 256)
    x = block1(x, 256)
    x = block1(x, 256)
    x = block1(x, 256)
    x = block1(x, 256)
    x = block1(x, 256)
    x = block1(x, 256)
    x = block1(x, 256)
    x = block1(x, 256)
    x = block1(x, 256)
    x = block1(x, 256)
    x = block1(x, 256)
    x = block1(x, 256)
    x = block1(x, 256)
    x = block1(x, 256)
    x = block1(x, 256)
    x = block1(x, 256)
    x = block1(x, 256)
    
    x = GlobalAveragePooling2D(name='avg_pool')(x)
    x = Dense(361, activation='softmax', name='fc1000')(x)

    model = Model(inputs, x, name='resnet50')
    return model

model = ResNet50(include_top=True,
                 input_tensor=None,
                 input_shape=(19, 19, 19),
                 pooling=False)
opt = Nadam(learning_rate = 0.0001)
model.compile(optimizer = opt,
              loss='sparse_categorical_crossentropy',
                metrics=['accuracy'])
model.summary()
# Out:
# Model: "resnet50"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 19, 19, 19)  0           []
#                                 ]
#
#  activation (Activation)        (None, 19, 19, 19)   0           ['input_1[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 19, 19, 256)  4864        ['activation[0][0]']
#
#  activation_1 (Activation)      (None, 19, 19, 256)  0           ['conv2d_1[0][0]']
#
#  zero_padding2d (ZeroPadding2D)  (None, 21, 21, 256)  0          ['activation_1[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 19, 19, 256)  589824      ['zero_padding2d[0][0]']
#
#  activation_2 (Activation)      (None, 19, 19, 256)  0           ['conv2d_2[0][0]']
#
#  conv2d (Conv2D)                (None, 19, 19, 1024  20480       ['activation[0][0]']
#                                 )
#
#  conv2d_3 (Conv2D)              (None, 19, 19, 1024  263168      ['activation_2[0][0]']
#                                 )
#
#  add (Add)                      (None, 19, 19, 1024  0           ['conv2d[0][0]',
#                                 )                                 'conv2d_3[0][0]']
#
#  activation_3 (Activation)      (None, 19, 19, 1024  0           ['add[0][0]']
#                                 )
#
#  conv2d_4 (Conv2D)              (None, 19, 19, 256)  262144      ['activation_3[0][0]']
#
#  activation_4 (Activation)      (None, 19, 19, 256)  0           ['conv2d_4[0][0]']
#
#  zero_padding2d_1 (ZeroPadding2  (None, 21, 21, 256)  0          ['activation_4[0][0]']
#  D)
#
#  conv2d_5 (Conv2D)              (None, 19, 19, 256)  589824      ['zero_padding2d_1[0][0]']
#
#  activation_5 (Activation)      (None, 19, 19, 256)  0           ['conv2d_5[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 19, 19, 1024  263168      ['activation_5[0][0]']
#                                 )
#
#  add_1 (Add)                    (None, 19, 19, 1024  0           ['add[0][0]',
#                                 )                                 'conv2d_6[0][0]']
#
#  activation_6 (Activation)      (None, 19, 19, 1024  0           ['add_1[0][0]']
#                                 )
#
#  conv2d_7 (Conv2D)              (None, 19, 19, 256)  262144      ['activation_6[0][0]']
#
#  activation_7 (Activation)      (None, 19, 19, 256)  0           ['conv2d_7[0][0]']
#
#  zero_padding2d_2 (ZeroPadding2  (None, 21, 21, 256)  0          ['activation_7[0][0]']
#  D)
#
#  conv2d_8 (Conv2D)              (None, 19, 19, 256)  589824      ['zero_padding2d_2[0][0]']
#
#  activation_8 (Activation)      (None, 19, 19, 256)  0           ['conv2d_8[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 19, 19, 1024  263168      ['activation_8[0][0]']
#                                 )
#
#  add_2 (Add)                    (None, 19, 19, 1024  0           ['add_1[0][0]',
#                                 )                                 'conv2d_9[0][0]']
#
#  activation_9 (Activation)      (None, 19, 19, 1024  0           ['add_2[0][0]']
#                                 )
#
#  conv2d_10 (Conv2D)             (None, 19, 19, 256)  262144      ['activation_9[0][0]']
#
#  activation_10 (Activation)     (None, 19, 19, 256)  0           ['conv2d_10[0][0]']
#
#  zero_padding2d_3 (ZeroPadding2  (None, 21, 21, 256)  0          ['activation_10[0][0]']
#  D)
#
#  conv2d_11 (Conv2D)             (None, 19, 19, 256)  589824      ['zero_padding2d_3[0][0]']
#
#  activation_11 (Activation)     (None, 19, 19, 256)  0           ['conv2d_11[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 19, 19, 1024  263168      ['activation_11[0][0]']
#                                 )
#
#  add_3 (Add)                    (None, 19, 19, 1024  0           ['add_2[0][0]',
#                                 )                                 'conv2d_12[0][0]']
#
#  activation_12 (Activation)     (None, 19, 19, 1024  0           ['add_3[0][0]']
#                                 )
#
#  conv2d_13 (Conv2D)             (None, 19, 19, 256)  262144      ['activation_12[0][0]']
#
#  activation_13 (Activation)     (None, 19, 19, 256)  0           ['conv2d_13[0][0]']
#
#  zero_padding2d_4 (ZeroPadding2  (None, 21, 21, 256)  0          ['activation_13[0][0]']
#  D)
#
#  conv2d_14 (Conv2D)             (None, 19, 19, 256)  589824      ['zero_padding2d_4[0][0]']
#
#  activation_14 (Activation)     (None, 19, 19, 256)  0           ['conv2d_14[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 19, 19, 1024  263168      ['activation_14[0][0]']
#                                 )
#
#  add_4 (Add)                    (None, 19, 19, 1024  0           ['add_3[0][0]',
#                                 )                                 'conv2d_15[0][0]']
#
#  activation_15 (Activation)     (None, 19, 19, 1024  0           ['add_4[0][0]']
#                                 )
#
#  conv2d_16 (Conv2D)             (None, 19, 19, 256)  262144      ['activation_15[0][0]']
#
#  activation_16 (Activation)     (None, 19, 19, 256)  0           ['conv2d_16[0][0]']
#
#  zero_padding2d_5 (ZeroPadding2  (None, 21, 21, 256)  0          ['activation_16[0][0]']
#  D)
#
#  conv2d_17 (Conv2D)             (None, 19, 19, 256)  589824      ['zero_padding2d_5[0][0]']
#
#  activation_17 (Activation)     (None, 19, 19, 256)  0           ['conv2d_17[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 19, 19, 1024  263168      ['activation_17[0][0]']
#                                 )
#
#  add_5 (Add)                    (None, 19, 19, 1024  0           ['add_4[0][0]',
#                                 )                                 'conv2d_18[0][0]']
#
#  activation_18 (Activation)     (None, 19, 19, 1024  0           ['add_5[0][0]']
#                                 )
#
#  conv2d_19 (Conv2D)             (None, 19, 19, 256)  262144      ['activation_18[0][0]']
#
#  activation_19 (Activation)     (None, 19, 19, 256)  0           ['conv2d_19[0][0]']
#
#  zero_padding2d_6 (ZeroPadding2  (None, 21, 21, 256)  0          ['activation_19[0][0]']
#  D)
#
#  conv2d_20 (Conv2D)             (None, 19, 19, 256)  589824      ['zero_padding2d_6[0][0]']
#
#  activation_20 (Activation)     (None, 19, 19, 256)  0           ['conv2d_20[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 19, 19, 1024  263168      ['activation_20[0][0]']
#                                 )
#
#  add_6 (Add)                    (None, 19, 19, 1024  0           ['add_5[0][0]',
#                                 )                                 'conv2d_21[0][0]']
#
#  activation_21 (Activation)     (None, 19, 19, 1024  0           ['add_6[0][0]']
#                                 )
#
#  conv2d_22 (Conv2D)             (None, 19, 19, 256)  262144      ['activation_21[0][0]']
#
#  activation_22 (Activation)     (None, 19, 19, 256)  0           ['conv2d_22[0][0]']
#
#  zero_padding2d_7 (ZeroPadding2  (None, 21, 21, 256)  0          ['activation_22[0][0]']
#  D)
#
#  conv2d_23 (Conv2D)             (None, 19, 19, 256)  589824      ['zero_padding2d_7[0][0]']
#
#  activation_23 (Activation)     (None, 19, 19, 256)  0           ['conv2d_23[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 19, 19, 1024  263168      ['activation_23[0][0]']
#                                 )
#
#  add_7 (Add)                    (None, 19, 19, 1024  0           ['add_6[0][0]',
#                                 )                                 'conv2d_24[0][0]']
#
#  activation_24 (Activation)     (None, 19, 19, 1024  0           ['add_7[0][0]']
#                                 )
#
#  conv2d_25 (Conv2D)             (None, 19, 19, 256)  262144      ['activation_24[0][0]']
#
#  activation_25 (Activation)     (None, 19, 19, 256)  0           ['conv2d_25[0][0]']
#
#  zero_padding2d_8 (ZeroPadding2  (None, 21, 21, 256)  0          ['activation_25[0][0]']
#  D)
#
#  conv2d_26 (Conv2D)             (None, 19, 19, 256)  589824      ['zero_padding2d_8[0][0]']
#
#  activation_26 (Activation)     (None, 19, 19, 256)  0           ['conv2d_26[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 19, 19, 1024  263168      ['activation_26[0][0]']
#                                 )
#
#  add_8 (Add)                    (None, 19, 19, 1024  0           ['add_7[0][0]',
#                                 )                                 'conv2d_27[0][0]']
#
#  activation_27 (Activation)     (None, 19, 19, 1024  0           ['add_8[0][0]']
#                                 )
#
#  conv2d_28 (Conv2D)             (None, 19, 19, 256)  262144      ['activation_27[0][0]']
#
#  activation_28 (Activation)     (None, 19, 19, 256)  0           ['conv2d_28[0][0]']
#
#  zero_padding2d_9 (ZeroPadding2  (None, 21, 21, 256)  0          ['activation_28[0][0]']
#  D)
#
#  conv2d_29 (Conv2D)             (None, 19, 19, 256)  589824      ['zero_padding2d_9[0][0]']
#
#  activation_29 (Activation)     (None, 19, 19, 256)  0           ['conv2d_29[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 19, 19, 1024  263168      ['activation_29[0][0]']
#                                 )
#
#  add_9 (Add)                    (None, 19, 19, 1024  0           ['add_8[0][0]',
#                                 )                                 'conv2d_30[0][0]']
#
#  activation_30 (Activation)     (None, 19, 19, 1024  0           ['add_9[0][0]']
#                                 )
#
#  conv2d_31 (Conv2D)             (None, 19, 19, 256)  262144      ['activation_30[0][0]']
#
#  activation_31 (Activation)     (None, 19, 19, 256)  0           ['conv2d_31[0][0]']
#
#  zero_padding2d_10 (ZeroPadding  (None, 21, 21, 256)  0          ['activation_31[0][0]']
#  2D)
#
#  conv2d_32 (Conv2D)             (None, 19, 19, 256)  589824      ['zero_padding2d_10[0][0]']
#
#  activation_32 (Activation)     (None, 19, 19, 256)  0           ['conv2d_32[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 19, 19, 1024  263168      ['activation_32[0][0]']
#                                 )
#
#  add_10 (Add)                   (None, 19, 19, 1024  0           ['add_9[0][0]',
#                                 )                                 'conv2d_33[0][0]']
#
#  activation_33 (Activation)     (None, 19, 19, 1024  0           ['add_10[0][0]']
#                                 )
#
#  conv2d_34 (Conv2D)             (None, 19, 19, 256)  262144      ['activation_33[0][0]']
#
#  activation_34 (Activation)     (None, 19, 19, 256)  0           ['conv2d_34[0][0]']
#
#  zero_padding2d_11 (ZeroPadding  (None, 21, 21, 256)  0          ['activation_34[0][0]']
#  2D)
#
#  conv2d_35 (Conv2D)             (None, 19, 19, 256)  589824      ['zero_padding2d_11[0][0]']
#
#  activation_35 (Activation)     (None, 19, 19, 256)  0           ['conv2d_35[0][0]']
#
#  conv2d_36 (Conv2D)             (None, 19, 19, 1024  263168      ['activation_35[0][0]']
#                                 )
#
#  add_11 (Add)                   (None, 19, 19, 1024  0           ['add_10[0][0]',
#                                 )                                 'conv2d_36[0][0]']
#
#  activation_36 (Activation)     (None, 19, 19, 1024  0           ['add_11[0][0]']
#                                 )
#
#  conv2d_37 (Conv2D)             (None, 19, 19, 256)  262144      ['activation_36[0][0]']
#
#  activation_37 (Activation)     (None, 19, 19, 256)  0           ['conv2d_37[0][0]']
#
#  zero_padding2d_12 (ZeroPadding  (None, 21, 21, 256)  0          ['activation_37[0][0]']
#  2D)
#
#  conv2d_38 (Conv2D)             (None, 19, 19, 256)  589824      ['zero_padding2d_12[0][0]']
#
#  activation_38 (Activation)     (None, 19, 19, 256)  0           ['conv2d_38[0][0]']
#
#  conv2d_39 (Conv2D)             (None, 19, 19, 1024  263168      ['activation_38[0][0]']
#                                 )
#
#  add_12 (Add)                   (None, 19, 19, 1024  0           ['add_11[0][0]',
#                                 )                                 'conv2d_39[0][0]']
#
#  activation_39 (Activation)     (None, 19, 19, 1024  0           ['add_12[0][0]']
#                                 )
#
#  conv2d_40 (Conv2D)             (None, 19, 19, 256)  262144      ['activation_39[0][0]']
#
#  activation_40 (Activation)     (None, 19, 19, 256)  0           ['conv2d_40[0][0]']
#
#  zero_padding2d_13 (ZeroPadding  (None, 21, 21, 256)  0          ['activation_40[0][0]']
#  2D)
#
#  conv2d_41 (Conv2D)             (None, 19, 19, 256)  589824      ['zero_padding2d_13[0][0]']
#
#  activation_41 (Activation)     (None, 19, 19, 256)  0           ['conv2d_41[0][0]']
#
#  conv2d_42 (Conv2D)             (None, 19, 19, 1024  263168      ['activation_41[0][0]']
#                                 )
#
#  add_13 (Add)                   (None, 19, 19, 1024  0           ['add_12[0][0]',
#                                 )                                 'conv2d_42[0][0]']
#
#  activation_42 (Activation)     (None, 19, 19, 1024  0           ['add_13[0][0]']
#                                 )
#
#  conv2d_43 (Conv2D)             (None, 19, 19, 256)  262144      ['activation_42[0][0]']
#
#  activation_43 (Activation)     (None, 19, 19, 256)  0           ['conv2d_43[0][0]']
#
#  zero_padding2d_14 (ZeroPadding  (None, 21, 21, 256)  0          ['activation_43[0][0]']
#  2D)
#
#  conv2d_44 (Conv2D)             (None, 19, 19, 256)  589824      ['zero_padding2d_14[0][0]']
#
#  activation_44 (Activation)     (None, 19, 19, 256)  0           ['conv2d_44[0][0]']
#
#  conv2d_45 (Conv2D)             (None, 19, 19, 1024  263168      ['activation_44[0][0]']
#                                 )
#
#  add_14 (Add)                   (None, 19, 19, 1024  0           ['add_13[0][0]',
#                                 )                                 'conv2d_45[0][0]']
#
#  activation_45 (Activation)     (None, 19, 19, 1024  0           ['add_14[0][0]']
#                                 )
#
#  conv2d_46 (Conv2D)             (None, 19, 19, 256)  262144      ['activation_45[0][0]']
#
#  activation_46 (Activation)     (None, 19, 19, 256)  0           ['conv2d_46[0][0]']
#
#  zero_padding2d_15 (ZeroPadding  (None, 21, 21, 256)  0          ['activation_46[0][0]']
#  2D)
#
#  conv2d_47 (Conv2D)             (None, 19, 19, 256)  589824      ['zero_padding2d_15[0][0]']
#
#  activation_47 (Activation)     (None, 19, 19, 256)  0           ['conv2d_47[0][0]']
#
#  conv2d_48 (Conv2D)             (None, 19, 19, 1024  263168      ['activation_47[0][0]']
#                                 )
#
#  add_15 (Add)                   (None, 19, 19, 1024  0           ['add_14[0][0]',
#                                 )                                 'conv2d_48[0][0]']
#
#  avg_pool (GlobalAveragePooling  (None, 1024)        0           ['add_15[0][0]']
#  2D)
#
#  fc1000 (Dense)                 (None, 361)          370025      ['avg_pool[0][0]']
# ==================================================================================================
# Total params: 17,975,401
# Trainable params: 17,975,401
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
callback1 = tf.keras.callbacks.EarlyStopping(monitor='val_loss', min_delta=0, 
                                patience=3, verbose=0, mode='min'
                                 , restore_best_weights=True)
# callback1 = tf.keras.callbacks.EarlyStopping(monitor='val_accuracy', min_delta=0, 
#                                 patience=3, verbose=0, mode='max'
#                                  , restore_best_weights=True)
callback2 = keras.callbacks.ModelCheckpoint('./models/model_kyu_v2_b64_f256_l49_{epoch:02d}_{val_accuracy:.4f}.h5', 
                                            monitor='val_accuracy', 
                                            verbose=0, save_best_only=False, save_weights_only=False, 
                                            mode='max', save_freq="epoch")

# %%
# model = load_model('./models/model_kyu_f256_l88_mir_02_0.0035.h5')

# %%
history = model.fit(
    dataset,
    epochs = 500,
#     steps_per_epoch = train_steps,
    validation_data = dataset_valid,
#     validation_steps = val_steps,
    callbacks = [callback1, callback2]
)
# Out:
# Epoch 1/500
# 169592/169592 [==============================] - 34888s 206ms/step - loss: 2.1832 - accuracy: 0.4734 - val_loss: 1.8773 - val_accuracy: 0.5109
# Epoch 2/500
# 169592/169592 [==============================] - 35596s 210ms/step - loss: 1.8144 - accuracy: 0.5210 - val_loss: 1.7849 - val_accuracy: 0.5221
# Epoch 3/500
# 169592/169592 [==============================] - 35638s 210ms/step - loss: 1.7402 - accuracy: 0.5320 - val_loss: 1.7495 - val_accuracy: 0.5270
# Epoch 4/500
# 169592/169592 [==============================] - 35420s 209ms/step - loss: 1.6978 - accuracy: 0.5391 - val_loss: 1.7341 - val_accuracy: 0.5298
# Epoch 5/500
# 169592/169592 [==============================] - 36482s 215ms/step - loss: 1.6700 - accuracy: 0.5439 - val_loss: 1.7275 - val_accuracy: 0.5306
# Epoch 6/500
# 169592/169592 [==============================] - 35426s 209ms/step - loss: 1.6507 - accuracy: 0.5473 - val_loss: 1.7261 - val_accuracy: 0.5309
# Epoch 7/500
#   5439/169592 [..............................] - ETA: 8:33:20 - loss: 1.6394 - accuracy: 0.5485
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 history = model.fit(
#       2     dataset,
#       3     epochs = 500,
#       4 #     steps_per_epoch = train_steps,
#       5     validation_data = dataset_valid,
#       6 #     validation_steps = val_steps,
#       7     callbacks = [callback1, callback2]
#       8 )
#
# File ~\AppData\Local\anaconda3\envs\tensorflow2_9_1\lib\site-packages\keras\utils\traceback_utils.py:64, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      62 filtered_tb = None
#      63 try:
# ---> 64   return fn(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\AppData\Local\anaconda3\envs\tensorflow2_9_1\lib\site-packages\keras\engine\training.py:1409, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1402 with tf.profiler.experimental.Trace(
#    1403     'train',
#    1404     epoch_num=epoch,
#    1405     step_num=step,
#    1406     batch_size=batch_size,
#    1407     _r=1):
#    1408   callbacks.on_train_batch_begin(step)
# -> 1409   tmp_logs = self.train_function(iterator)
#    1410   if data_handler.should_sync:
#    1411     context.async_wait()
#
# File ~\AppData\Local\anaconda3\envs\tensorflow2_9_1\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\AppData\Local\anaconda3\envs\tensorflow2_9_1\lib\site-packages\tensorflow\python\eager\def_function.py:915, in Function.__call__(self, *args, **kwds)
#     912 compiler = "xla" if self._jit_compile else "nonXla"
#     914 with OptionalXlaContext(self._jit_compile):
# --> 915   result = self._call(*args, **kwds)
#     917 new_tracing_count = self.experimental_get_tracing_count()
#     918 without_tracing = (tracing_count == new_tracing_count)
#
# File ~\AppData\Local\anaconda3\envs\tensorflow2_9_1\lib\site-packages\tensorflow\python\eager\def_function.py:947, in Function._call(self, *args, **kwds)
#     944   self._lock.release()
#     945   # In this case we have created variables on the first call, so we run the
#     946   # defunned version which is guaranteed to never create variables.
# --> 947   return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     948 elif self._stateful_fn is not None:
#     949   # Release the lock early so that multiple threads can perform the call
#     950   # in parallel.
#     951   self._lock.release()
#
# File ~\AppData\Local\anaconda3\envs\tensorflow2_9_1\lib\site-packages\tensorflow\python\eager\function.py:2453, in Function.__call__(self, *args, **kwargs)
#    2450 with self._lock:
#    2451   (graph_function,
#    2452    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 2453 return graph_function._call_flat(
#    2454     filtered_flat_args, captured_inputs=graph_function.captured_inputs)
#
# File ~\AppData\Local\anaconda3\envs\tensorflow2_9_1\lib\site-packages\tensorflow\python\eager\function.py:1860, in ConcreteFunction._call_flat(self, args, captured_inputs, cancellation_manager)
#    1856 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1857 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1858     and executing_eagerly):
#    1859   # No tape is watching; skip to running the function.
# -> 1860   return self._build_call_outputs(self._inference_function.call(
#    1861       ctx, args, cancellation_manager=cancellation_manager))
#    1862 forward_backward = self._select_forward_and_backward_functions(
#    1863     args,
#    1864     possible_gradient_type,
#    1865     executing_eagerly)
#    1866 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~\AppData\Local\anaconda3\envs\tensorflow2_9_1\lib\site-packages\tensorflow\python\eager\function.py:497, in _EagerDefinedFunction.call(self, ctx, args, cancellation_manager)
#     495 with _InterpolateFunctionError(self):
#     496   if cancellation_manager is None:
# --> 497     outputs = execute.execute(
#     498         str(self.signature.name),
#     499         num_outputs=self._num_outputs,
#     500         inputs=args,
#     501         attrs=attrs,
#     502         ctx=ctx)
#     503   else:
#     504     outputs = execute.execute_with_cancellation(
#     505         str(self.signature.name),
#     506         num_outputs=self._num_outputs,
#    (...)
#     509         ctx=ctx,
#     510         cancellation_manager=cancellation_manager)
#
# File ~\AppData\Local\anaconda3\envs\tensorflow2_9_1\lib\site-packages\tensorflow\python\eager\execute.py:54, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52 try:
#      53   ctx.ensure_initialized()
# ---> 54   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                       inputs, attrs, num_outputs)
#      56 except core._NotOkStatusException as e:
#      57   if name is not None:
#
# KeyboardInterrupt:

# %%
result = model.evaluate(
    dataset_valid,
    steps = val_steps
)
# Out:
# 11374/21176 [===============>..............] - ETA: 43:34 - loss: 1.6519 - accuracy: 0.5500
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 result = model.evaluate(
#       2     dataset_valid,
#       3     steps = val_steps
#       4 )
#
# File ~\AppData\Local\anaconda3\envs\tensorflow2_9_1\lib\site-packages\keras\utils\traceback_utils.py:64, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      62 filtered_tb = None
#      63 try:
# ---> 64   return fn(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\AppData\Local\anaconda3\envs\tensorflow2_9_1\lib\site-packages\keras\engine\training.py:1756, in Model.evaluate(self, x, y, batch_size, verbose, sample_weight, steps, callbacks, max_queue_size, workers, use_multiprocessing, return_dict, **kwargs)
#    1754 with tf.profiler.experimental.Trace('test', step_num=step, _r=1):
#    1755   callbacks.on_test_batch_begin(step)
# -> 1756   tmp_logs = self.test_function(iterator)
#    1757   if data_handler.should_sync:
#    1758     context.async_wait()
#
# File ~\AppData\Local\anaconda3\envs\tensorflow2_9_1\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\AppData\Local\anaconda3\envs\tensorflow2_9_1\lib\site-packages\tensorflow\python\eager\def_function.py:915, in Function.__call__(self, *args, **kwds)
#     912 compiler = "xla" if self._jit_compile else "nonXla"
#     914 with OptionalXlaContext(self._jit_compile):
# --> 915   result = self._call(*args, **kwds)
#     917 new_tracing_count = self.experimental_get_tracing_count()
#     918 without_tracing = (tracing_count == new_tracing_count)
#
# File ~\AppData\Local\anaconda3\envs\tensorflow2_9_1\lib\site-packages\tensorflow\python\eager\def_function.py:954, in Function._call(self, *args, **kwds)
#     951 self._lock.release()
#     952 # In this case we have not created variables on the first call. So we can
#     953 # run the first trace but we should fail if variables are created.
# --> 954 results = self._stateful_fn(*args, **kwds)
#     955 if self._created_variables and not ALLOW_DYNAMIC_VARIABLE_CREATION:
#     956   raise ValueError("Creating variables on a non-first call to a function"
#     957                    " decorated with tf.function.")
#
# File ~\AppData\Local\anaconda3\envs\tensorflow2_9_1\lib\site-packages\tensorflow\python\eager\function.py:2453, in Function.__call__(self, *args, **kwargs)
#    2450 with self._lock:
#    2451   (graph_function,
#    2452    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 2453 return graph_function._call_flat(
#    2454     filtered_flat_args, captured_inputs=graph_function.captured_inputs)
#
# File ~\AppData\Local\anaconda3\envs\tensorflow2_9_1\lib\site-packages\tensorflow\python\eager\function.py:1860, in ConcreteFunction._call_flat(self, args, captured_inputs, cancellation_manager)
#    1856 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1857 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1858     and executing_eagerly):
#    1859   # No tape is watching; skip to running the function.
# -> 1860   return self._build_call_outputs(self._inference_function.call(
#    1861       ctx, args, cancellation_manager=cancellation_manager))
#    1862 forward_backward = self._select_forward_and_backward_functions(
#    1863     args,
#    1864     possible_gradient_type,
#    1865     executing_eagerly)
#    1866 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~\AppData\Local\anaconda3\envs\tensorflow2_9_1\lib\site-packages\tensorflow\python\eager\function.py:497, in _EagerDefinedFunction.call(self, ctx, args, cancellation_manager)
#     495 with _InterpolateFunctionError(self):
#     496   if cancellation_manager is None:
# --> 497     outputs = execute.execute(
#     498         str(self.signature.name),
#     499         num_outputs=self._num_outputs,
#     500         inputs=args,
#     501         attrs=attrs,
#     502         ctx=ctx)
#     503   else:
#     504     outputs = execute.execute_with_cancellation(
#     505         str(self.signature.name),
#     506         num_outputs=self._num_outputs,
#    (...)
#     509         ctx=ctx,
#     510         cancellation_manager=cancellation_manager)
#
# File ~\AppData\Local\anaconda3\envs\tensorflow2_9_1\lib\site-packages\tensorflow\python\eager\execute.py:54, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52 try:
#      53   ctx.ensure_initialized()
# ---> 54   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                       inputs, attrs, num_outputs)
#      56 except core._NotOkStatusException as e:
#      57   if name is not None:
#
# KeyboardInterrupt:

# %% [markdown]
# model.save('./models/model_kyu_resnet50_withpp_1.h5')

# %% [markdown]
# ## ALL DONE!
#
# For using the model and creating a submission file, follow the notebook **Create Public Upload CSV.ipynb**

# %% [markdown]
# # End of Tutorial
#
# You are free to use more modern NN architectures, a better pre-processing, feature extraction methods to achieve much better accuracy!
